# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic["Zeros"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Zeros'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
titanic["Zeros"] = 0

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
#      Zeros
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# ...

# %%
titanic["Zeros"] = "Zero"

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck Zeros
# 0           0       3    male  22.0      1      0   7.2500        S  NaN  Zero
# 1           1       1  female  38.0      1      0  71.2833        C    C  Zero
# 2           1       3  female  26.0      0      0   7.9250        S  NaN  Zero
# 3           1       1  female  35.0      1      0  53.1000        S    C  Zero
# 4           0       3    male  35.0      0      0   8.0500        S  NaN  Zero
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...   ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN  Zero
# 887         1       1  female  19.0      0      0  30.0000        S    B  Zero
# 888         0       3  female   NaN      1      2  23.4500        S  NaN  Zero
# 889         1       1    male  26.0      0      0  30.0000        C    C  Zero
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN  Zero
#
# [891 rows x 10 columns]

# %%
titanic.Ones = 1 # with attribute notation can only select existing columns

# %%
titanic          # with attribute notation can only select existing columns
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck Zeros
# 0           0       3    male  22.0      1      0   7.2500        S  NaN  Zero
# 1           1       1  female  38.0      1      0  71.2833        C    C  Zero
# 2           1       3  female  26.0      0      0   7.9250        S  NaN  Zero
# 3           1       1  female  35.0      1      0  53.1000        S    C  Zero
# 4           0       3    male  35.0      0      0   8.0500        S  NaN  Zero
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...   ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN  Zero
# 887         1       1  female  19.0      0      0  30.0000        S    B  Zero
# 888         0       3  female   NaN      1      2  23.4500        S  NaN  Zero
# 889         1       1    male  26.0      0      0  30.0000        C    C  Zero
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN  Zero
#
# [891 rows x 10 columns]

# %%
titanic.Ones
# Out:
# 1
