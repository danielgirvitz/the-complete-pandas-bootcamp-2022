# %%
import pandas as pd

# %%
player = ["Lionel Messi", "Cristiano Ronaldo", "Neymar Junior", "Kylian Mbappe", "Manuel Neuer"]
nationality = ["Argentina", "Portugal", "Brasil", "France", "Germany"]
club = ["FC Barcelona", "Juventus FC", "Paris SG", "Paris SG", "FC Bayern" ]
world_champion = [False, False, False, True, True]
height = [1.70, 1.87, 1.75, 1.78, 1.93]
goals = [45, 44, 28, 21, 0]

# %%
dic = {"Player":player, "Nationality":nationality, "Club":club, 
        "World_Champion":world_champion, "Height":height, "Goals_2018":goals
       }

# %%
df = pd.DataFrame(data = dic)
df
# Out:
#               Player Nationality          Club  World_Champion  Height  \
# 0       Lionel Messi   Argentina  FC Barcelona           False    1.70
# 1  Cristiano Ronaldo    Portugal   Juventus FC           False    1.87
# 2      Neymar Junior      Brasil      Paris SG           False    1.75
# 3      Kylian Mbappe      France      Paris SG            True    1.78
# 4       Manuel Neuer     Germany     FC Bayern            True    1.93
#
#    Goals_2018
# 0          45
# 1          44
# 2          28
# 3          21
# 4           0

# %%
players = df

# %% [markdown]
# ## Adding one row

# %%
players.loc[5, :] = ["Sergio Ramos",
                     "Spain",
                     "Real Madrid",
                     True,
                     1.84,
                     5]
players
# Out:
#               Player Nationality          Club World_Champion  Height  \
# 0       Lionel Messi   Argentina  FC Barcelona          False    1.70
# 1  Cristiano Ronaldo    Portugal   Juventus FC          False    1.87
# 2      Neymar Junior      Brasil      Paris SG          False    1.75
# 3      Kylian Mbappe      France      Paris SG           True    1.78
# 4       Manuel Neuer     Germany     FC Bayern           True    1.93
# 5       Sergio Ramos       Spain   Real Madrid           True    1.84
#
#    Goals_2018
# 0        45.0
# 1        44.0
# 2        28.0
# 3        21.0
# 4         0.0
# 5         5.0

# %% [markdown]
# ## Adding many rows

# %%
new = pd.DataFrame(
    data = [["Mohamed Salah", "Egypt", "FC Liverpool", False, 1.75, 44],
            ["Luis Suarez", "Uruguay", "FC Barcelona", False, 1.82, 31]],
    columns = players.columns
)

# %%
new
# Out:
#           Player Nationality          Club  World_Champion  Height  Goals_2018
# 0  Mohamed Salah       Egypt  FC Liverpool           False    1.75          44
# 1    Luis Suarez     Uruguay  FC Barcelona           False    1.82          31

# %%
players = players.append(new, ignore_index = True)
# Out:
# C:\Users\dan.girvitz\AppData\Local\Temp\ipykernel_17988\2268971855.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   players = players.append(new, ignore_index = True)

# %%
players
# Out:
#               Player Nationality          Club World_Champion  Height  \
# 0       Lionel Messi   Argentina  FC Barcelona          False    1.70
# 1  Cristiano Ronaldo    Portugal   Juventus FC          False    1.87
# 2      Neymar Junior      Brasil      Paris SG          False    1.75
# 3      Kylian Mbappe      France      Paris SG           True    1.78
# 4       Manuel Neuer     Germany     FC Bayern           True    1.93
# 5       Sergio Ramos       Spain   Real Madrid           True    1.84
# 6      Mohamed Salah       Egypt  FC Liverpool          False    1.75
# 7        Luis Suarez     Uruguay  FC Barcelona          False    1.82
#
#    Goals_2018
# 0        45.0
# 1        44.0
# 2        28.0
# 3        21.0
# 4         0.0
# 5         5.0
# 6        44.0
# 7        31.0
