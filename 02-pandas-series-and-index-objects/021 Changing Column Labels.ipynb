# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck'],
#       dtype='object')

# %%
titanic.columns[0]
# Out:
# 'survived'

# %%
titanic.columns[0] = "Alive"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 titanic.columns[0] = "Alive"
#
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:5035, in Index.__setitem__(self, key, value)
#    5033 @final
#    5034 def __setitem__(self, key, value):
# -> 5035     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
titanic.columns = ['alive', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
       'embarked', 'deck']

# %%
titanic.head()
# Out:
#    alive  pclass     sex   age  sibsp  parch     fare embarked deck
# 0      0       3    male  22.0      1      0   7.2500        S  NaN
# 1      1       1  female  38.0      1      0  71.2833        C    C
# 2      1       3  female  26.0      0      0   7.9250        S  NaN
# 3      1       1  female  35.0      1      0  53.1000        S    C
# 4      0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.columns.name # No name for column index object

# %%
titanic.columns.name = "Pass_Charact" # Set name for column index object

# %%
titanic.head()
# Out:
# Pass_Charact  alive  pclass     sex   age  sibsp  parch     fare embarked deck
# 0                 0       3    male  22.0      1      0   7.2500        S  NaN
# 1                 1       1  female  38.0      1      0  71.2833        C    C
# 2                 1       3  female  26.0      0      0   7.9250        S  NaN
# 3                 1       1  female  35.0      1      0  53.1000        S    C
# 4                 0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.index.name = "Passenger_no"

# %%
titanic.head()
# Out:
# Pass_Charact  alive  pclass     sex   age  sibsp  parch     fare embarked deck
# Passenger_no
# 0                 0       3    male  22.0      1      0   7.2500        S  NaN
# 1                 1       1  female  38.0      1      0  71.2833        C    C
# 2                 1       3  female  26.0      0      0   7.9250        S  NaN
# 3                 1       1  female  35.0      1      0  53.1000        S    C
# 4                 0       3    male  35.0      0      0   8.0500        S  NaN
